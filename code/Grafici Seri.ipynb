# %%
import pandas as pd
import seaborn as sb
import os
import numpy as np
import matplotlib.pyplot as plt

res = pd.DataFrame()

# %%
r = pd.read_csv('resultsV03.csv')
res = r[1:]
res
# Out:
#      Unnamed: 0         var              vsa                    vca  initTime  \
# 1             1           P  anti_first_fail               indomain  0.685657
# 2             2           P  anti_first_fail           indomain_max  0.673988
# 3             3           P  anti_first_fail        indomain_median  0.698428
# 4             4           P  anti_first_fail           indomain_min  0.774093
# 5             5           P  anti_first_fail        indomain_random  0.699089
# ..          ...         ...              ...                    ...       ...
# 320         320  scheduling         smallest  indomain_split_random  0.680709
# 321         321          ea  anti_first_fail               indomain  0.701106
# 322         322          ea  anti_first_fail           indomain_max  0.832448
# 323         323          ea  anti_first_fail        indomain_median  0.680075
# 324         324          ea  anti_first_fail           indomain_min  0.735823
#
#      solveTime  solutions  variables  propagators  propagations      nodes  \
# 1      7.95799       10.0     5925.0       2322.0     4581997.0    71191.0
# 2      5.29487        4.0     5925.0       2322.0     3966641.0    23917.0
# 3      5.06141       10.0     5925.0       2322.0     3471483.0    21267.0
# 4      8.05122       10.0     5925.0       2322.0     4616259.0    68987.0
# 5    165.02400        7.0     5925.0       2322.0    60713329.0   855163.0
# ..         ...        ...        ...          ...           ...        ...
# 320    4.84633       10.0     5925.0       2322.0     3537677.0    20919.0
# 321  180.24500        0.0     5925.0       2322.0   167453913.0  1305507.0
# 322  180.25000        0.0     5925.0       2322.0   123602234.0   568992.0
# 323  180.24500        0.0     5925.0       2322.0   168370320.0  1376693.0
# 324  180.26900        0.0     5925.0       2322.0   165805101.0  1373532.0
#
#      failures  restarts  peakDepth
# 1     36794.0       0.0       26.0
# 2     11954.0       0.0       34.0
# 3     10621.0       0.0       25.0
# 4     34482.0       0.0       26.0
# 5    427572.0       0.0       55.0
# ..        ...       ...        ...
# 320   10447.0       0.0       25.0
# 321  701103.0       0.0       25.0
# 322  284490.0       0.0       27.0
# 323  688340.0       0.0       25.0
# 324  686760.0       0.0       25.0
#
# [324 rows x 14 columns]

# %% [markdown]
# Elimino i valori che hano un tempo di risoluzione maggiore di 180(probabilmente hanno raggiunto il timeout)

# %%
df_val = res[res['solveTime'] < 180].copy()
df_val = df_val.reset_index()
df_val = df_val.drop(columns=['index','Unnamed: 0', 'variables', 'propagators', 'restarts'])

# %% [markdown]
# Conto i valori, pre diverse categorie che hanno un tempo di risoluzione minore di 5 secondi.
# ### Si può vedere come scheduling sembri avere dei tempi tendenzialmente migliori di altri

# %%
df_val[df_val['solveTime'] < 4.9].sort_values(by=['solveTime'])
# Out:
#             var               vsa                     vca  initTime  \
# 64            P        occurrence  indomain_reverse_split  0.674926
# 60            P        occurrence            indomain_max  0.676076
# 198  scheduling           largest  indomain_reverse_split  0.676157
# 185  scheduling       input_order                indomain  0.675920
# 193  scheduling           largest                indomain  0.681472
# 209  scheduling  most_constrained                indomain  0.677303
# 208  scheduling        max_regret   indomain_split_random  0.686727
# 168  scheduling         dom_w_deg   indomain_split_random  0.676138
# 68            P          smallest            indomain_max  0.677304
# 215  scheduling  most_constrained          indomain_split  0.683001
# 167  scheduling         dom_w_deg          indomain_split  0.679169
# 191  scheduling       input_order          indomain_split  0.675904
# 172  scheduling        first_fail            indomain_min  0.690969
# 216  scheduling  most_constrained   indomain_split_random  0.678671
# 178  scheduling            impact            indomain_max  0.778362
# 182  scheduling            impact  indomain_reverse_split  0.670310
# 220  scheduling        occurrence            indomain_min  0.676362
# 228  scheduling          smallest            indomain_min  0.742310
# 223  scheduling        occurrence          indomain_split  0.742241
# 183  scheduling            impact          indomain_split  0.721322
# 162  scheduling         dom_w_deg            indomain_max  0.852367
# 199  scheduling           largest          indomain_split  0.668289
# 196  scheduling           largest            indomain_min  0.719426
# 227  scheduling          smallest         indomain_median  0.693302
# 232  scheduling          smallest   indomain_split_random  0.680709
# 177  scheduling            impact                indomain  0.683502
# 159  scheduling   anti_first_fail          indomain_split  0.697818
# 218  scheduling        occurrence            indomain_max  0.854134
# 72            P          smallest  indomain_reverse_split  0.696590
# 70            P          smallest            indomain_min  0.679917
# 179  scheduling            impact         indomain_median  0.675262
# 180  scheduling            impact            indomain_min  0.679989
# 156  scheduling   anti_first_fail            indomain_min  0.736329
# 186  scheduling       input_order            indomain_max  0.670198
# 160  scheduling   anti_first_fail   indomain_split_random  0.697751
# 195  scheduling           largest         indomain_median  0.701677
# 194  scheduling           largest            indomain_max  0.696517
# 225  scheduling          smallest                indomain  0.843597
# 184  scheduling            impact   indomain_split_random  0.696066
#
#      solveTime  solutions  propagations    nodes  failures  peakDepth
# 64     4.45827        3.0     3717134.0  20715.0   10353.0       35.0
# 60     4.60084        3.0     3913874.0  21907.0   10949.0       35.0
# 198    4.78073        6.0     3546574.0  19709.0    9847.0       33.0
# 185    4.78292       10.0     3537317.0  20919.0   10447.0       25.0
# 193    4.78605       10.0     3549530.0  20919.0   10447.0       25.0
# 209    4.78660       10.0     3537317.0  20919.0   10447.0       25.0
# 208    4.78753       10.0     3537317.0  20919.0   10447.0       25.0
# 168    4.78953       10.0     3537317.0  20919.0   10447.0       25.0
# 68     4.79146        6.0     3575236.0  19717.0    9851.0       33.0
# 215    4.79300       10.0     3537317.0  20919.0   10447.0       25.0
# 167    4.79850       10.0     3537317.0  20919.0   10447.0       25.0
# 191    4.79881       10.0     3537317.0  20919.0   10447.0       25.0
# 172    4.80214       10.0     3537317.0  20919.0   10447.0       25.0
# 216    4.80319       10.0     3549890.0  20919.0   10447.0       25.0
# 178    4.80581        6.0     3546468.0  19709.0    9847.0       33.0
# 182    4.80760        6.0     3546468.0  19709.0    9847.0       33.0
# 220    4.80834       10.0     3537317.0  20919.0   10447.0       25.0
# 228    4.82649       10.0     3537317.0  20919.0   10447.0       25.0
# 223    4.82820       10.0     3537761.0  20919.0   10447.0       25.0
# 183    4.83501       10.0     3537317.0  20919.0   10447.0       25.0
# 162    4.84089        6.0     3546468.0  19709.0    9847.0       33.0
# 199    4.84241       10.0     3537317.0  20919.0   10447.0       25.0
# 196    4.84339       10.0     3537677.0  20919.0   10447.0       25.0
# 227    4.84422       10.0     3537317.0  20919.0   10447.0       25.0
# 232    4.84633       10.0     3537677.0  20919.0   10447.0       25.0
# 177    4.85362       10.0     3549890.0  20919.0   10447.0       25.0
# 159    4.85499       10.0     3537317.0  20919.0   10447.0       25.0
# 218    4.85716        6.0     3546468.0  19709.0    9847.0       33.0
# 72     4.85728        6.0     3622464.0  19553.0    9769.0       32.0
# 70     4.85966       10.0     3553379.0  21545.0   10760.0       25.0
# 179    4.86303       10.0     3537317.0  20919.0   10447.0       25.0
# 180    4.86725       10.0     3537317.0  20919.0   10447.0       25.0
# 156    4.87199       10.0     3537317.0  20919.0   10447.0       25.0
# 186    4.87264        6.0     3546468.0  19709.0    9847.0       33.0
# 160    4.87409       10.0     3549102.0  20919.0   10447.0       25.0
# 195    4.87911       10.0     3537317.0  20919.0   10447.0       25.0
# 194    4.87982        6.0     3546468.0  19709.0    9847.0       33.0
# 225    4.88570       10.0     3549530.0  20919.0   10447.0       25.0
# 184    4.88878       10.0     3537317.0  20919.0   10447.0       25.0

# %%
#df_val[df_val['solveTime'] == df_val['solveTime'].min()]
df_val[df_val['solveTime']< 5].groupby(by=['var']).count()
# Out:
#             vsa  vca  initTime  solveTime  solutions  propagations  nodes  \
# var
# P             8    8         8          8          8             8      8
# scheduling   57   57        57         57         57            57     57
#
#             failures  peakDepth
# var
# P                  8          8
# scheduling        57         57

# %%
df_val[df_val['solveTime']< 5].groupby(by=['vsa']).count()
# Out:
#                   var  vca  initTime  solveTime  solutions  propagations  \
# vsa
# anti_first_fail     7    7         7          7          7             7
# dom_w_deg           7    7         7          7          7             7
# first_fail          4    4         4          4          4             4
# impact              7    7         7          7          7             7
# input_order         7    7         7          7          7             7
# largest             7    7         7          7          7             7
# max_regret          2    2         2          2          2             2
# most_constrained    5    5         5          5          5             5
# occurrence          9    9         9          9          9             9
# smallest           10   10        10         10         10            10
#
#                   nodes  failures  peakDepth
# vsa
# anti_first_fail       7         7          7
# dom_w_deg             7         7          7
# first_fail            4         4          4
# impact                7         7          7
# input_order           7         7          7
# largest               7         7          7
# max_regret            2         2          2
# most_constrained      5         5          5
# occurrence            9         9          9
# smallest             10        10         10

# %%
df_val[df_val['solveTime']< 5].groupby(by=['vca']).count()
# Out:
#                         var  vsa  initTime  solveTime  solutions  \
# vca
# indomain                 11   11        11         11         11
# indomain_max              9    9         9          9          9
# indomain_median           8    8         8          8          8
# indomain_min              9    9         9          9          9
# indomain_reverse_split   10   10        10         10         10
# indomain_split            8    8         8          8          8
# indomain_split_random    10   10        10         10         10
#
#                         propagations  nodes  failures  peakDepth
# vca
# indomain                          11     11        11         11
# indomain_max                       9      9         9          9
# indomain_median                    8      8         8          8
# indomain_min                       9      9         9          9
# indomain_reverse_split            10     10        10         10
# indomain_split                     8      8         8          8
# indomain_split_random             10     10        10         10

# %%
#df_val

# %%
f = plt.figure(figsize=(18,10))
gs = f.add_gridspec(1,1)
ax = f.add_subplot(gs[0, 0])
sb.boxplot(x=df_val['vsa'], y=df_val['solveTime'], hue=df_val['vca'])
# Out:
# <AxesSubplot:xlabel='vsa', ylabel='solveTime'>

# %%
f = plt.figure(figsize=(18,10))
gs = f.add_gridspec(1,1)
ax = f.add_subplot(gs[0, 0])
sb.boxplot(x=df_val['vca'], y=df_val['solveTime'], hue=df_val['vsa'])
# Out:
# <AxesSubplot:xlabel='vca', ylabel='solveTime'>

# %%
df_val.groupby(['vca','vsa']).mean(['solveTime'])['solveTime'].plot(figsize=(30,6))
# Out:
# <AxesSubplot:xlabel='vca,vsa'>

# %%
f = plt.figure(figsize=(30, 50))
gs = f.add_gridspec(4, 1)
ax = f.add_subplot(gs[0, 0])
sb.lineplot(x=df_val['vsa'], y=df_val['solveTime'], hue=df_val['var'])
ax = f.add_subplot(gs[1, 0])
sb.lineplot(x=df_val['vsa'], y=df_val['peakDepth'], hue=df_val['var'])
ax = f.add_subplot(gs[2, 0])
sb.lineplot(x=df_val['vsa'], y=df_val['nodes'], hue=df_val['var'])
ax = f.add_subplot(gs[3, 0])
sb.lineplot(x=df_val['vsa'], y=df_val['failures'], hue=df_val['var'])
# Out:
# <AxesSubplot:xlabel='vsa', ylabel='failures'>

# %%
f = plt.figure(figsize=(30, 50))
gs = f.add_gridspec(4, 1)
ax = f.add_subplot(gs[0, 0])
sb.barplot(x=df_val['vsa'], y=df_val['solveTime'], hue=df_val['var'])
ax = f.add_subplot(gs[1, 0])
sb.barplot(x=df_val['vsa'], y=df_val['peakDepth'], hue=df_val['var'])
ax = f.add_subplot(gs[2, 0])
sb.barplot(x=df_val['vsa'], y=df_val['nodes'], hue=df_val['var'])
ax = f.add_subplot(gs[3, 0])
sb.barplot(x=df_val['vsa'], y=df_val['failures'], hue=df_val['var'])
# Out:
# <AxesSubplot:xlabel='vsa', ylabel='failures'>

# %%
f = plt.figure(figsize=(30, 50))
gs = f.add_gridspec(4, 1)
ax = f.add_subplot(gs[0, 0])
sb.barplot(x=df_val['var'], y=df_val['solveTime'], hue=df_val['vsa'])
ax = f.add_subplot(gs[1, 0])
sb.barplot(x=df_val['var'], y=df_val['peakDepth'], hue=df_val['vsa'])
ax = f.add_subplot(gs[2, 0])
sb.barplot(x=df_val['var'], y=df_val['nodes'], hue=df_val['vsa'])
ax = f.add_subplot(gs[3, 0])
sb.barplot(x=df_val['var'], y=df_val['failures'], hue=df_val['vsa'])
# Out:
# <AxesSubplot:xlabel='var', ylabel='failures'>

# %%
f = plt.figure(figsize=(30, 50))
gs = f.add_gridspec(4, 1)
ax = f.add_subplot(gs[0, 0])
sb.barplot(x=df_val['var'], y=df_val['solveTime'], hue=df_val['vca'])
ax = f.add_subplot(gs[1, 0])
sb.barplot(x=df_val['var'], y=df_val['peakDepth'], hue=df_val['vca'])
ax = f.add_subplot(gs[2, 0])
sb.barplot(x=df_val['var'], y=df_val['nodes'], hue=df_val['vca'])
ax = f.add_subplot(gs[3, 0])
sb.barplot(x=df_val['var'], y=df_val['failures'], hue=df_val['vca'])
# Out:
# <AxesSubplot:xlabel='var', ylabel='failures'>

# %%
df_val.sort_values(by=['solutions'])['solutions'].plot(figsize=(18,6))
# Out:
# <AxesSubplot:>

# %%
df_val.groupby('var')['solveTime'].describe()
# Out:
#             count       mean        std      min       25%      50%       75%  \
# var
# P            75.0  15.836493  31.392322  4.45827  5.508445  6.26105  13.60190
# X            78.0  18.717475  24.966060  5.44775  6.903265  9.52231  13.07110
# scheduling   80.0   4.979467   0.208036  4.78073  4.844012  4.92469   5.02786
#
#                   max
# var
# P           165.02400
# X           120.00400
# scheduling    5.77504
