# %%
import pandas as pd
import seaborn as sb
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
res = pd.DataFrame()

# %%
r = pd.read_csv('results.csv')
res = r[1:]
res
# Out:
#      Unnamed: 0             var              vsa                     vca  \
# 1             1               P  anti_first_fail                indomain
# 2             2               P  anti_first_fail            indomain_max
# 3             3               P  anti_first_fail         indomain_median
# 4             4               P  anti_first_fail            indomain_min
# 5             5               P  anti_first_fail         indomain_random
# ..          ...             ...              ...                     ...
# 476         476  pizzas_carried         smallest            indomain_min
# 477         477  pizzas_carried         smallest         indomain_random
# 478         478  pizzas_carried         smallest  indomain_reverse_split
# 479         479  pizzas_carried         smallest          indomain_split
# 480         480  pizzas_carried         smallest   indomain_split_random
#
#      initTime  solveTime  solutions  variables  propagators  propagations  \
# 1    0.787915    17.3448        2.0     4911.0       3667.0     4259181.0
# 2    0.795561    27.7348        7.0     4911.0       3667.0     6985594.0
# 3    0.914775    13.0522        2.0     4911.0       3667.0     3526902.0
# 4    0.792005    16.5851        2.0     4911.0       3667.0     4298015.0
# 5    0.832605    20.2603        5.0     4911.0       3667.0     4925968.0
# ..        ...        ...        ...        ...          ...           ...
# 476  0.775236    48.2143        8.0     4911.0       3667.0    17192562.0
# 477  0.781583    34.1006        3.0     4911.0       3667.0     9911885.0
# 478  0.780916    27.9778        5.0     4911.0       3667.0     8443586.0
# 479  0.782991    17.1076        3.0     4911.0       3667.0     5108441.0
# 480  0.789097    48.3943        8.0     4911.0       3667.0    17192562.0
#
#        nodes  failures  restarts  peakDepth
# 1    16613.0    9088.0       0.0       75.0
# 2    25235.0   12600.0       0.0       58.0
# 3    12888.0    6440.0       0.0       76.0
# 4    15037.0    7512.0       0.0       75.0
# 5    18247.0    9119.0       0.0       77.0
# ..       ...       ...       ...        ...
# 476  93897.0   46941.0       0.0       63.0
# 477  41375.0   20681.0       0.0       59.0
# 478  36344.0   18161.0       0.0       54.0
# 479  19822.0    9897.0       0.0       69.0
# 480  93897.0   46941.0       0.0       63.0
#
# [480 rows x 14 columns]

# %%
r[r['solveTime']<3.0]
# Out:
#      Unnamed: 0 var               vsa                     vca  initTime  \
# 97           97   X        first_fail                indomain  0.810897
# 98           98   X        first_fail            indomain_max  0.862376
# 99           99   X        first_fail         indomain_median  0.799859
# 100         100   X        first_fail            indomain_min  0.812694
# 101         101   X        first_fail         indomain_random  0.819561
# 102         102   X        first_fail  indomain_reverse_split  0.809728
# 103         103   X        first_fail          indomain_split  0.813888
# 104         104   X        first_fail   indomain_split_random  0.823140
# 137         137   X  most_constrained                indomain  0.774694
# 138         138   X  most_constrained            indomain_max  0.962800
# 139         139   X  most_constrained         indomain_median  0.780198
# 140         140   X  most_constrained            indomain_min  0.779473
# 141         141   X  most_constrained         indomain_random  0.778550
# 142         142   X  most_constrained  indomain_reverse_split  0.780008
# 143         143   X  most_constrained          indomain_split  0.784990
# 144         144   X  most_constrained   indomain_split_random  0.778506
#
#      solveTime  solutions  variables  propagators  propagations   nodes  \
# 97     2.38032        9.0     4911.0       3667.0      815064.0  1562.0
# 98     2.25804        5.0     4911.0       3667.0      537160.0  1007.0
# 99     2.42692        6.0     4911.0       3667.0      721944.0  1563.0
# 100    2.76744        9.0     4911.0       3667.0      799992.0  1937.0
# 101    1.92334        4.0     4911.0       3667.0      502131.0  1065.0
# 102    2.07329        5.0     4911.0       3667.0      485407.0  1001.0
# 103    2.68649        9.0     4911.0       3667.0      781878.0  1953.0
# 104    2.80083        9.0     4911.0       3667.0      799992.0  1937.0
# 137    2.22472        9.0     4911.0       3667.0      815064.0  1562.0
# 138    2.08910        5.0     4911.0       3667.0      537160.0  1007.0
# 139    2.31865        6.0     4911.0       3667.0      721944.0  1563.0
# 140    2.68699        9.0     4911.0       3667.0      799992.0  1937.0
# 141    1.85022        4.0     4911.0       3667.0      502131.0  1065.0
# 142    1.98802        5.0     4911.0       3667.0      485407.0  1001.0
# 143    2.61319        9.0     4911.0       3667.0      781878.0  1953.0
# 144    2.68262        9.0     4911.0       3667.0      799992.0  1937.0
#
#      failures  restarts  peakDepth
# 97      969.0       0.0       14.0
# 98      499.0       0.0       20.0
# 99      776.0       0.0       18.0
# 100     960.0       0.0       21.0
# 101     529.0       0.0       20.0
# 102     496.0       0.0       21.0
# 103     968.0       0.0       24.0
# 104     960.0       0.0       21.0
# 137     969.0       0.0       14.0
# 138     499.0       0.0       20.0
# 139     776.0       0.0       18.0
# 140     960.0       0.0       21.0
# 141     529.0       0.0       20.0
# 142     496.0       0.0       21.0
# 143     968.0       0.0       24.0
# 144     960.0       0.0       21.0

# %%
corr = res.corr()
f, ax = plt.subplots(figsize=(15,15))
cmap = sb.diverging_palette(230, 20, as_cmap=True)
sb.heatmap(corr.round(4), cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <AxesSubplot:>

# %%
res.groupby(['var', 'vsa'],)["solveTime"].plot(figsize=(12,6),ylim=(0,305))
# Out:
# var             vsa
# P               anti_first_fail     AxesSubplot(0.125,0.125;0.775x0.755)
#                 dom_w_deg           AxesSubplot(0.125,0.125;0.775x0.755)
#                 first_fail          AxesSubplot(0.125,0.125;0.775x0.755)
#                 impact              AxesSubplot(0.125,0.125;0.775x0.755)
#                 input_order         AxesSubplot(0.125,0.125;0.775x0.755)
#                 largest             AxesSubplot(0.125,0.125;0.775x0.755)
#                 max_regret          AxesSubplot(0.125,0.125;0.775x0.755)
#                 most_constrained    AxesSubplot(0.125,0.125;0.775x0.755)
#                 occurrence          AxesSubplot(0.125,0.125;0.775x0.755)
#                 smallest            AxesSubplot(0.125,0.125;0.775x0.755)
# X               anti_first_fail     AxesSubplot(0.125,0.125;0.775x0.755)
#                 dom_w_deg           AxesSubplot(0.125,0.125;0.775x0.755)
#                 first_fail          AxesSubplot(0.125,0.125;0.775x0.755)
#                 impact              AxesSubplot(0.125,0.125;0.775x0.755)
#                 input_order         AxesSubplot(0.125,0.125;0.775x0.755)
#                 largest             AxesSubplot(0.125,0.125;0.775x0.755)
#                 max_regret          AxesSubplot(0.125,0.125;0.775x0.755)
#                 most_constrained    AxesSubplot(0.125,0.125;0.775x0.755)
#                 occurrence          AxesSubplot(0.125,0.125;0.775x0.755)
#                 smallest            AxesSubplot(0.125,0.125;0.775x0.755)
# distances       anti_first_fail     AxesSubplot(0.125,0.125;0.775x0.755)
#                 dom_w_deg           AxesSubplot(0.125,0.125;0.775x0.755)
#                 first_fail          AxesSubplot(0.125,0.125;0.775x0.755)
#                 impact              AxesSubplot(0.125,0.125;0.775x0.755)
#                 input_order         AxesSubplot(0.125,0.125;0.775x0.755)
#                 largest             AxesSubplot(0.125,0.125;0.775x0.755)
#                 max_regret          AxesSubplot(0.125,0.125;0.775x0.755)
#                 most_constrained    AxesSubplot(0.125,0.125;0.775x0.755)
#                 occurrence          AxesSubplot(0.125,0.125;0.775x0.755)
#                 smallest            AxesSubplot(0.125,0.125;0.775x0.755)
# ea              anti_first_fail     AxesSubplot(0.125,0.125;0.775x0.755)
#                 dom_w_deg           AxesSubplot(0.125,0.125;0.775x0.755)
#                 first_fail          AxesSubplot(0.125,0.125;0.775x0.755)
#                 impact              AxesSubplot(0.125,0.125;0.775x0.755)
#                 input_order         AxesSubplot(0.125,0.125;0.775x0.755)
#                 largest             AxesSubplot(0.125,0.125;0.775x0.755)
#                 max_regret          AxesSubplot(0.125,0.125;0.775x0.755)
#                 most_constrained    AxesSubplot(0.125,0.125;0.775x0.755)
#                 occurrence          AxesSubplot(0.125,0.125;0.775x0.755)
#                 smallest            AxesSubplot(0.125,0.125;0.775x0.755)
# pizzas_carried  anti_first_fail     AxesSubplot(0.125,0.125;0.775x0.755)
# scheduling      anti_first_fail     AxesSubplot(0.125,0.125;0.775x0.755)
#                 dom_w_deg           AxesSubplot(0.125,0.125;0.775x0.755)
#                 first_fail          AxesSubplot(0.125,0.125;0.775x0.755)
#                 impact              AxesSubplot(0.125,0.125;0.775x0.755)
#                 input_order         AxesSubplot(0.125,0.125;0.775x0.755)
#                 largest             AxesSubplot(0.125,0.125;0.775x0.755)
#                 max_regret          AxesSubplot(0.125,0.125;0.775x0.755)
#                 most_constrained    AxesSubplot(0.125,0.125;0.775x0.755)
#                 occurrence          AxesSubplot(0.125,0.125;0.775x0.755)
#                 smallest            AxesSubplot(0.125,0.125;0.775x0.755)
# Name: solveTime, dtype: object

# %%
res.groupby(['var','vca'])["solveTime"].plot(figsize=(12,6))
# Out:
# var             vca
# P               indomain                  AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_max              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_median           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_min              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_random           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_reverse_split    AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split            AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split_random     AxesSubplot(0.125,0.125;0.775x0.755)
# X               indomain                  AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_max              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_median           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_min              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_random           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_reverse_split    AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split            AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split_random     AxesSubplot(0.125,0.125;0.775x0.755)
# distances       indomain                  AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_max              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_median           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_min              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_random           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_reverse_split    AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split            AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split_random     AxesSubplot(0.125,0.125;0.775x0.755)
# ea              indomain                  AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_max              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_median           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_min              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_random           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_reverse_split    AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split            AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split_random     AxesSubplot(0.125,0.125;0.775x0.755)
# pizzas_carried  indomain                  AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_max              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_median           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_min              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_random           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_reverse_split    AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split            AxesSubplot(0.125,0.125;0.775x0.755)
# scheduling      indomain                  AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_max              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_median           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_min              AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_random           AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_reverse_split    AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split            AxesSubplot(0.125,0.125;0.775x0.755)
#                 indomain_split_random     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: solveTime, dtype: object

# %%
res.groupby(['vsa'])["solveTime"].mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='vsa'>

# %%
res.groupby(['vca'])["solveTime"].mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='vca'>

# %%
res.groupby(['vsa'])["nodes"].mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='vsa'>

# %%
res.groupby(['vca'])["nodes"].mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='vca'>

# %%
res.groupby(['vsa'])["failures"].mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='vsa'>

# %%
res.groupby(['vca'])["failures"].mean().plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='vca'>

# %%
res.groupby(['vsa'])["propagations"].plot(figsize=(12,6))
# Out:
# vsa
# anti_first_fail     AxesSubplot(0.125,0.125;0.775x0.755)
# dom_w_deg           AxesSubplot(0.125,0.125;0.775x0.755)
# first_fail          AxesSubplot(0.125,0.125;0.775x0.755)
# impact              AxesSubplot(0.125,0.125;0.775x0.755)
# input_order         AxesSubplot(0.125,0.125;0.775x0.755)
# largest             AxesSubplot(0.125,0.125;0.775x0.755)
# max_regret          AxesSubplot(0.125,0.125;0.775x0.755)
# most_constrained    AxesSubplot(0.125,0.125;0.775x0.755)
# occurrence          AxesSubplot(0.125,0.125;0.775x0.755)
# smallest            AxesSubplot(0.125,0.125;0.775x0.755)
# Name: propagations, dtype: object

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
# 2D-arrays from DataFrame
#x1 = ["anti_first_fail", "dom_w_deg", "first_fail", "impact", "input_order", "largest", "max_regret", "most_constrained", "occurrence", "smallest"]
#y1 = ["indomain", "indomain_max", "indomain_median", "indomain_min","indomain_random","indomain_reverse_split","indomain_split","indomain_split_random"]

#df=res['vsa','vca', 'solveTime'].unstack().reset_index()
#df.columns=["x","y","z"]
df = pd.DataFrame({'x': res['vsa'], 'y': res['vca'], 'z': res['solveTime']}, index=range(len(res)))

df['x']=pd.Categorical(df['x'])
df['x']=df['x'].cat.codes

df['y']=pd.Categorical(df['y'])
df['y']=df['y'].cat.codes
 
# Make the plot
#fig = plt.figure()
#ax = fig.gca(projection='3d')
#ax.plot_trisurf(df['y'], df['x'], df['z'], cmap=plt.cm.viridis, linewidth=0.2)
#plt.show()#

#fig = plt.figure()
#ax = fig.gca(projection='3d')
#surf=ax.plot_trisurf(df['y'], df['x'], df['z'], cmap=plt.cm.viridis, linewidth=0.2)
#fig.colorbar( surf, shrink=0.5, aspect=5)
#plt.show()
 
# Rotate it
fig = plt.figure(figsize=(5,5))
ax = fig.gca(projection='3d')
surf=ax.plot_trisurf(df['y'], df['x'], df['z'], cmap=plt.cm.viridis, linewidth=0.2)
ax.view_init(25, 265)
plt.show()
# Out:
# /tmp/ipykernel_38098/3189659532.py:32: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# # Grafici con dataset pulito da NaN

# %%
df_val = res[res['variables'] == 4911.0].copy()
df_val = df_val.reset_index()
df_val = df_val.drop(columns=['index','Unnamed: 0'])

# %%
df_val.groupby(['var']).describe()['solveTime']
# Out:
#                 count        mean         std        min         25%  \
# var
# P                80.0   18.717303    5.596583   12.84800   13.895925
# X                61.0   98.709010  528.550892    1.85022    2.800830
# distances        33.0  300.282091    0.001860  300.27800  300.281000
# ea               39.0  300.281051    0.002316  300.27700  300.279000
# pizzas_carried    7.0   40.957943   11.259098   26.58080   33.016500
# scheduling       80.0   15.839920    4.367611   12.63100   12.745600
#
#                       50%         75%        max
# var
# P                16.37810   23.690200    35.0224
# X                 6.70147    8.458320  4112.8900
# distances       300.28200  300.283000   300.2860
# ea              300.28100  300.282500   300.2880
# pizzas_carried   41.80560   47.061450    58.1633
# scheduling       12.79195   18.651075    23.2840

# %%
df_val.groupby(['vca'])['solveTime'].mean().plot(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='vca'>

# %%
df_val.groupby(['vsa'])['solveTime'].mean().plot(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='vsa'>

# %%
df_val.groupby(['var'])['solveTime'].mean().plot(figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='var'>

# %%
df_val[df_val['solveTime']<5.0 ].sort_values(by=['solveTime'])
# Out:
#     var               vsa                     vca  initTime  solveTime  \
# 129   X  most_constrained         indomain_random  0.778550    1.85022
# 94    X        first_fail         indomain_random  0.819561    1.92334
# 130   X  most_constrained  indomain_reverse_split  0.780008    1.98802
# 95    X        first_fail  indomain_reverse_split  0.809728    2.07329
# 126   X  most_constrained            indomain_max  0.962800    2.08910
# 125   X  most_constrained                indomain  0.774694    2.22472
# 91    X        first_fail            indomain_max  0.862376    2.25804
# 127   X  most_constrained         indomain_median  0.780198    2.31865
# 90    X        first_fail                indomain  0.810897    2.38032
# 92    X        first_fail         indomain_median  0.799859    2.42692
# 131   X  most_constrained          indomain_split  0.784990    2.61319
# 132   X  most_constrained   indomain_split_random  0.778506    2.68262
# 96    X        first_fail          indomain_split  0.813888    2.68649
# 128   X  most_constrained            indomain_min  0.779473    2.68699
# 93    X        first_fail            indomain_min  0.812694    2.76744
# 97    X        first_fail   indomain_split_random  0.823140    2.80083
# 120   X        max_regret            indomain_max  0.799203    3.81868
# 119   X        max_regret                indomain  0.790888    4.23152
# 121   X        max_regret         indomain_median  0.793417    4.86175
#
#      solutions  variables  propagators  propagations   nodes  failures  \
# 129        4.0     4911.0       3667.0      502131.0  1065.0     529.0
# 94         4.0     4911.0       3667.0      502131.0  1065.0     529.0
# 130        5.0     4911.0       3667.0      485407.0  1001.0     496.0
# 95         5.0     4911.0       3667.0      485407.0  1001.0     496.0
# 126        5.0     4911.0       3667.0      537160.0  1007.0     499.0
# 125        9.0     4911.0       3667.0      815064.0  1562.0     969.0
# 91         5.0     4911.0       3667.0      537160.0  1007.0     499.0
# 127        6.0     4911.0       3667.0      721944.0  1563.0     776.0
# 90         9.0     4911.0       3667.0      815064.0  1562.0     969.0
# 92         6.0     4911.0       3667.0      721944.0  1563.0     776.0
# 131        9.0     4911.0       3667.0      781878.0  1953.0     968.0
# 132        9.0     4911.0       3667.0      799992.0  1937.0     960.0
# 96         9.0     4911.0       3667.0      781878.0  1953.0     968.0
# 128        9.0     4911.0       3667.0      799992.0  1937.0     960.0
# 93         9.0     4911.0       3667.0      799992.0  1937.0     960.0
# 97         9.0     4911.0       3667.0      799992.0  1937.0     960.0
# 120        9.0     4911.0       3667.0     1071148.0  2097.0    1040.0
# 119        9.0     4911.0       3667.0     1317333.0  2187.0    1385.0
# 121        4.0     4911.0       3667.0     1382531.0  2691.0    1342.0
#
#      restarts  peakDepth
# 129       0.0       20.0
# 94        0.0       20.0
# 130       0.0       21.0
# 95        0.0       21.0
# 126       0.0       20.0
# 125       0.0       14.0
# 91        0.0       20.0
# 127       0.0       18.0
# 90        0.0       14.0
# 92        0.0       18.0
# 131       0.0       24.0
# 132       0.0       21.0
# 96        0.0       24.0
# 128       0.0       21.0
# 93        0.0       21.0
# 97        0.0       21.0
# 120       0.0       23.0
# 119       0.0       14.0
# 121       0.0       24.0

# %%
df_val[df_val['var'] == 'scheduling' ].sort_values(by=['solveTime']).T
# Out:
#                          228           241                    189  \
# var               scheduling    scheduling             scheduling
# vsa               max_regret    occurrence              dom_w_deg
# vca           indomain_split  indomain_min  indomain_split_random
# initTime            0.777981      0.779363               0.779941
# solveTime             12.631        12.649                12.6824
# solutions                2.0           2.0                    2.0
# variables             4911.0        4911.0                 4911.0
# propagators           3667.0        3667.0                 3667.0
# propagations       3537464.0     3537464.0              3537470.0
# nodes                12641.0       12641.0                12641.0
# failures              6316.0        6316.0                 6316.0
# restarts                 0.0           0.0                    0.0
# peakDepth               76.0          76.0                   76.0
#
#                          188              216              240  \
# var               scheduling       scheduling       scheduling
# vsa                dom_w_deg          largest       occurrence
# vca           indomain_split  indomain_median  indomain_median
# initTime            0.780178         0.779488         0.779074
# solveTime            12.6825          12.6892          12.6896
# solutions                2.0              2.0              2.0
# variables             4911.0           4911.0           4911.0
# propagators           3667.0           3667.0           3667.0
# propagations       3537470.0        3537470.0        3537470.0
# nodes                12641.0          12641.0          12641.0
# failures              6316.0           6316.0           6316.0
# restarts                 0.0              0.0              0.0
# peakDepth               76.0             76.0             76.0
#
#                           177              174                    213  \
# var                scheduling       scheduling             scheduling
# vsa           anti_first_fail  anti_first_fail            input_order
# vca              indomain_min         indomain  indomain_split_random
# initTime             0.779673         0.778698               0.781955
# solveTime             12.6898          12.6956                12.6963
# solutions                 2.0              2.0                    2.0
# variables              4911.0           4911.0                 4911.0
# propagators            3667.0           3667.0                 3667.0
# propagations        3537470.0        3537470.0              3537470.0
# nodes                 12641.0          12641.0                12641.0
# failures               6316.0           6316.0                 6316.0
# restarts                  0.0              0.0                    0.0
# peakDepth                76.0             76.0                   76.0
#
#                                 221  ...           223           215  \
# var                      scheduling  ...    scheduling    scheduling
# vsa                         largest  ...    max_regret       largest
# vca           indomain_split_random  ...  indomain_max  indomain_max
# initTime                   0.781287  ...      0.775594      0.777169
# solveTime                   12.7056  ...       22.9741       22.9778
# solutions                       2.0  ...           7.0           7.0
# variables                    4911.0  ...        4911.0        4911.0
# propagators                  3667.0  ...        3667.0        3667.0
# propagations              3537470.0  ...     6358086.0     6358086.0
# nodes                       12641.0  ...       23525.0       23525.0
# failures                     6316.0  ...       11745.0       11745.0
# restarts                        0.0  ...           0.0           0.0
# peakDepth                      76.0  ...          58.0          58.0
#
#                                  235                     179           207  \
# var                       scheduling              scheduling    scheduling
# vsa                 most_constrained         anti_first_fail   input_order
# vca           indomain_reverse_split  indomain_reverse_split  indomain_max
# initTime                    0.772236                0.862608      0.776563
# solveTime                    22.9856                 22.9885       23.0223
# solutions                        7.0                     7.0           7.0
# variables                     4911.0                  4911.0        4911.0
# propagators                   3667.0                  3667.0        3667.0
# propagations               6358626.0               6377033.0     6358086.0
# nodes                        23525.0                 23651.0       23525.0
# failures                     11745.0                 11808.0       11745.0
# restarts                         0.0                     0.0           0.0
# peakDepth                       58.0                    58.0          58.0
#
#                        247              175           199  \
# var             scheduling       scheduling    scheduling
# vsa               smallest  anti_first_fail        impact
# vca           indomain_max     indomain_max  indomain_max
# initTime          0.778692         0.773431      0.778574
# solveTime          23.0328          23.0391       23.0967
# solutions              7.0              7.0           7.0
# variables           4911.0           4911.0        4911.0
# propagators         3667.0           3667.0        3667.0
# propagations     6358086.0        6358086.0     6358086.0
# nodes              23525.0          23525.0       23525.0
# failures           11745.0          11745.0       11745.0
# restarts               0.0              0.0           0.0
# peakDepth             58.0             58.0          58.0
#
#                                  211           183
# var                       scheduling    scheduling
# vsa                      input_order     dom_w_deg
# vca           indomain_reverse_split  indomain_max
# initTime                    0.782485      0.776211
# solveTime                    23.1234        23.284
# solutions                        7.0           7.0
# variables                     4911.0        4911.0
# propagators                   3667.0        3667.0
# propagations               6358086.0     6358086.0
# nodes                        23525.0       23525.0
# failures                     11745.0       11745.0
# restarts                         0.0           0.0
# peakDepth                       58.0          58.0
#
# [13 rows x 80 columns]

# %%
df_val.min()
# Out:
# var                           P
# vsa             anti_first_fail
# vca                    indomain
# initTime               0.770659
# solveTime               1.85022
# solutions                   0.0
# variables                4911.0
# propagators              3667.0
# propagations           485407.0
# nodes                    1001.0
# failures                  496.0
# restarts                    0.0
# peakDepth                  13.0
# dtype: object
